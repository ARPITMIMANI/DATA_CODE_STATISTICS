# %%
# CREATE A BOX PLOT USING MATPLOTLIB .

import numpy as np
import matplotlib.pyplot as plt

a = np.random.normal ( loc=0 , scale=1 , size=100 )

plt.title("BOX PLOT")
plt.xlabel("X-AXIS")
plt.ylabel("Y-AXIS")

plt.boxplot(a)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

b = np.random.normal ( loc=2 , scale=4 , size=100 )

plt.title("BOX PLOT")
plt.xlabel("X-AXIS")
plt.ylabel("Y-AXIS")

plt.boxplot(b)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

c = np.random.normal ( loc=1 , scale=3 , size=10 )

plt.title("BOX PLOT")
plt.xlabel("X-AXIS")
plt.ylabel("Y-AXIS")

plt.boxplot(c)
plt.show()

# %%
# CREATE A BOX PLOT USING SEABORN .

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

d = np.random.normal ( loc=0 , scale=1 , size=100 )
sns.boxplot ( data=d )

plt.title("BOX PLOT")
plt.xlabel("X-AXIS")
plt.ylabel("Y-AXIS")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

e = np.random.normal ( loc=2 , scale=4 , size=100 )
sns.boxplot ( data=e )

plt.title("BOX PLOT")
plt.xlabel("X-AXIS")
plt.ylabel("Y-AXIS")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

f = np.random.normal ( loc=1 , scale=3 , size=10 )
sns.boxplot ( data=f )

plt.title("BOX PLOT")
plt.xlabel("X-AXIS")
plt.ylabel("Y-AXIS")
plt.show()
